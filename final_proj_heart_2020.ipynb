# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
dataset=pd.read_csv("C:/Users/oussa/Desktop/H&M Kaggle/archive/heart_2020_cleaned.csv")

# %%
dataset
# Out:
#        HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                No  16.60     Yes              No     No             3.0
# 1                No  20.34      No              No    Yes             0.0
# 2                No  26.58     Yes              No     No            20.0
# 3                No  24.21      No              No     No             0.0
# 4                No  23.71      No              No     No            28.0
# ...             ...    ...     ...             ...    ...             ...
# 319790          Yes  27.41     Yes              No     No             7.0
# 319791           No  29.84     Yes              No     No             0.0
# 319792           No  24.24      No              No     No             0.0
# 319793           No  32.81      No              No     No             0.0
# 319794           No  46.56      No              No     No             0.0
#
#         MentalHealth DiffWalking     Sex  AgeCategory      Race Diabetic  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
dataset.describe().transpose()
# Out:
#                    count       mean       std    min    25%    50%    75%  \
# BMI             319795.0  28.325399  6.356100  12.02  24.03  27.34  31.42
# PhysicalHealth  319795.0   3.371710  7.950850   0.00   0.00   0.00   2.00
# MentalHealth    319795.0   3.898366  7.955235   0.00   0.00   0.00   3.00
# SleepTime       319795.0   7.097075  1.436007   1.00   6.00   7.00   8.00
#
#                   max
# BMI             94.85
# PhysicalHealth  30.00
# MentalHealth    30.00
# SleepTime       24.00

# %%
dataset.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
dataset.AgeCategory
# Out:
# 0               55-59
# 1         80 or older
# 2               65-69
# 3               75-79
# 4               40-44
#              ...
# 319790          60-64
# 319791          35-39
# 319792          45-49
# 319793          25-29
# 319794    80 or older
# Name: AgeCategory, Length: 319795, dtype: object

# %%
dataset.AgeCategory.unique()
# Out:
# array(['55-59', '80 or older', '65-69', '75-79', '40-44', '70-74',
#        '60-64', '50-54', '45-49', '18-24', '35-39', '30-34', '25-29'],
#       dtype=object)

# %%
for i in dataset.columns :
    print(dataset[i].value_counts())
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64
# 26.63    3762
# 27.46    2767
# 27.44    2723
# 24.41    2696
# 27.12    2525
#          ...
# 50.43       1
# 51.48       1
# 37.01       1
# 13.08       1
# 81.46       1
# Name: BMI, Length: 3604, dtype: int64
# No     187887
# Yes    131908
# Name: Smoking, dtype: int64
# No     298018
# Yes     21777
# Name: AlcoholDrinking, dtype: int64
# No     307726
# Yes     12069
# Name: Stroke, dtype: int64
# 0.0     226589
# 30.0     19509
# 2.0      14880
# 1.0      10489
# 3.0       8617
# 5.0       7606
# 10.0      5453
# 15.0      5012
# 7.0       4629
# 4.0       4468
# 20.0      3216
# 14.0      2893
# 6.0       1270
# 25.0      1164
# 8.0        924
# 21.0       626
# 12.0       605
# 28.0       446
# 29.0       204
# 9.0        180
# 18.0       167
# 16.0       135
# 27.0       124
# 17.0       110
# 13.0        91
# 22.0        89
# 11.0        85
# 24.0        67
# 26.0        66
# 23.0        46
# ...

# %%
sns.displot(dataset.BMI)

# %%
sns.displot(dataset.PhysicalHealth)

# %%
sns.displot(dataset.SleepTime)

# %%
sns.displot(data=dataset, x="Smoking", hue="HeartDisease", multiple="stack")

# %%
sns.displot(data=dataset, x="AlcoholDrinking", hue="HeartDisease", multiple="stack")

# %%
sns.displot(data=dataset, x="AgeCategory", hue="HeartDisease", multiple="stack")

# %%
sns.displot(data=dataset, x="BMI", hue="HeartDisease", multiple="stack")

# %%
sns.displot(data=dataset, x="HeartDisease", hue="Race", multiple="stack")

# %%
g=sns.FacetGrid(data=dataset,col="HeartDisease",row='Race')
g.map(sns.histplot,'BMI')

# %%
g=sns.FacetGrid(data=dataset,col="HeartDisease",row='Smoking')
g.map(sns.histplot,'AlcoholDrinking')

# %%
def plot_correlation_map( df ):
    corr = df.corr()
    s , ax = plt.subplots( figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(
        corr, 
        cmap = cmap,
        square=True, 
        cbar_kws={ 'shrink' : .9 }, 
        ax=ax, 
        annot = True, 
        annot_kws = { 'fontsize' : 12 }
        )

# %%
plot_correlation_map(dataset)

# %%
sns.displot(data=dataset, x="GenHealth", hue="HeartDisease", multiple="stack")

# %%
sns.displot(data=dataset, x="GenHealth", hue="Race", multiple="stack")

# %%
def data_cleanup(df):

    if type(df)!=pd.core.frame.DataFrame:
        raise ValueError('input is not a pandas dataframe')
    working_df = df.copy()
    cols = working_df.columns
    converted_columns = {}
    for col in cols:
        if working_df[col].dtype == 'O':
            unique_values = working_df[col].unique()
            converted_values = {v:k for k,v in enumerate(unique_values)}
            for value in unique_values:
                working_df[col] = working_df[col].replace(value, converted_values[value])
            converted_columns[col] = converted_values
    return working_df, converted_columns

# %%
datset_c,coverted=data_cleanup(dataset)

# %%
datset_c
# Out:
#         HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0                  0  16.60        0                0       0             3.0
# 1                  0  20.34        1                0       1             0.0
# 2                  0  26.58        0                0       0            20.0
# 3                  0  24.21        1                0       0             0.0
# 4                  0  23.71        1                0       0            28.0
# ...              ...    ...      ...              ...     ...             ...
# 319790             1  27.41        0                0       0             7.0
# 319791             0  29.84        0                0       0             0.0
# 319792             0  24.24        1                0       0             0.0
# 319793             0  32.81        1                0       0             0.0
# 319794             0  46.56        1                0       0             0.0
#
# ...

# %%
plot_correlation_map(datset_c)

# %%
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
Y=datset_c['HeartDisease']
X=datset_c.drop('HeartDisease',axis='columns')
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=20)
clf=RandomForestClassifier(n_estimators=30)
clf.fit(X_train, Y_train)  
Y_pred=clf.predict(X_test)  
print("Accuracy:", metrics.accuracy_score(Y_test, Y_pred))
# Out:
# Accuracy: 0.9068309385700214

# %%
A=[]
for i in range(3,10):
    Y=datset_c['HeartDisease']
    X=datset_c.drop('HeartDisease',axis='columns')
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=20)
    clf=RandomForestClassifier(n_estimators=100*i)
    clf.fit(X_train, Y_train)  
    Y_pred=clf.predict(X_test)  
    A=A+[metrics.accuracy_score(Y_test, Y_pred)]
    print(A)
# Out:
# [0.9074563392173111]
# [0.9074563392173111, 0.9073468941040354]
# [0.9074563392173111, 0.9073468941040354, 0.9071749089260307]
# [0.9074563392173111, 0.9073468941040354, 0.9071749089260307, 0.9076126893791335]
# [0.9074563392173111, 0.9073468941040354, 0.9071749089260307, 0.9076126893791335, 0.9073781641363999]
# [0.9074563392173111, 0.9073468941040354, 0.9071749089260307, 0.9076126893791335, 0.9073781641363999, 0.9072999890554887]
# [0.9074563392173111, 0.9073468941040354, 0.9071749089260307, 0.9076126893791335, 0.9073781641363999, 0.9072999890554887, 0.9072687190231242]
